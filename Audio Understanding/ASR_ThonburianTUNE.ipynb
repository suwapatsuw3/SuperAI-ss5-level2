# %%
# !pip install -q datasets transformers evaluate huggingface_hub jiwer pythainlp

# %%
# %pip install --upgrade torch torchaudio
# Out:
# Requirement already satisfied: torch in /data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages (2.2.2+cpu)
# Collecting torch
#   Downloading torch-2.7.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Requirement already satisfied: torchaudio in /data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages (2.6.0)
# Collecting torchaudio
#   Downloading torchaudio-2.7.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: filelock in /data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages (from torch) (4.13.2)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in /home/siamai/.local/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages (from torch) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch)
#   Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch)
#   Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch)
#   Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch)
#   Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch)
#   Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch)
#   Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch)
#   Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch)
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch)
#   Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages (from torch) (1.11.1.6)
# Collecting triton==3.3.0 (from torch)
#   Downloading triton-3.3.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages (from triton==3.3.0->torch) (80.8.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/siamai/.local/lib/python3.10/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/siamai/.local/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)
# Downloading torch-2.7.0-cp310-cp310-manylinux_2_28_x86_64.whl (865.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.2/865.2 MB 91.9 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 105.1 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 106.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 106.8 MB/s eta 0:00:0000:01
# Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 133.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 90.0 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 108.9 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 109.1 MB/s eta 0:00:00a 0:00:01
# Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 106.4 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 110.6 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 90.9 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 94.5 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 105.2 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading triton-3.3.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (156.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.4/156.4 MB 92.1 MB/s eta 0:00:0000:0100:01
# Downloading torchaudio-2.7.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 82.7 MB/s eta 0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 90.3 MB/s eta 0:00:00
# Installing collected packages: nvidia-cusparselt-cu12, triton, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchaudio
#   Attempting uninstall: nvidia-cusparselt-cu12
#     Found existing installation: nvidia-cusparselt-cu12 0.6.2
#     Uninstalling nvidia-cusparselt-cu12-0.6.2:
#       Successfully uninstalled nvidia-cusparselt-cu12-0.6.2
#   Attempting uninstall: triton━━━━━━━━━━━━━━━━━━  0/17 [nvidia-cusparselt-cu12]
#     Found existing installation: triton 3.2.0  0/17 [nvidia-cusparselt-cu12]
#     Uninstalling triton-3.2.0:━━━━━━━━━━━━━━  0/17 [nvidia-cusparselt-cu12]
#       Successfully uninstalled triton-3.2.0━  0/17 [nvidia-cusparselt-cu12]
#   Attempting uninstall: sympy━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/17 [triton]
#     Found existing installation: sympy 1.13.1━━━━━━━━━━━━━━━━━  1/17 [triton]
#     Uninstalling sympy-1.13.1:m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/17 [sympy]
#       Successfully uninstalled sympy-1.13.1━━━━━━━━━━━━━━━━━━━━━━━  2/17 [sympy]
#   Attempting uninstall: nvidia-nvtx-cu12━━━━━━━━━━━━━━━━━━━━━━━━━━  2/17 [sympy]
#     Found existing installation: nvidia-nvtx-cu12 12.4.127━━━━  2/17 [sympy]
#     Uninstalling nvidia-nvtx-cu12-12.4.127:━━━━━━━━━━━━━━━━━━━  2/17 [sympy]
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127━━━━━━  2/17 [sympy]
#   Attempting uninstall: nvidia-nvjitlink-cu12━━━━━━━━━━━━━━━━━  2/17 [sympy]
#     Found existing installation: nvidia-nvjitlink-cu12 12.4.127  2/17 [sympy]
#     Uninstalling nvidia-nvjitlink-cu12-12.4.127:━━━━━━━━━━━━━━  2/17 [sympy]
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.4.127━  2/17 [sympy]
#   Attempting uninstall: nvidia-nccl-cu12━━━━━━━━━━━━━━━━━━━━━━━━━━  4/17 [nvidia-nvjitlink-cu12]
#     Found existing installation: nvidia-nccl-cu12 2.21.5━━━━━━  4/17 [nvidia-nvjitlink-cu12]
#     Uninstalling nvidia-nccl-cu12-2.21.5:━━━━━━━━━━━━━━━━━━━━━  4/17 [nvidia-nvjitlink-cu12]
#       Successfully uninstalled nvidia-nccl-cu12-2.21.5━━━━━━━━  4/17 [nvidia-nvjitlink-cu12]
#   Attempting uninstall: nvidia-curand-cu12━━━━━━━━━━━━━━━━━━━━━━━━  5/17 [nvidia-nccl-cu12]]
#     Found existing installation: nvidia-curand-cu12 10.3.5.147  5/17 [nvidia-nccl-cu12]
#     Uninstalling nvidia-curand-cu12-10.3.5.147:━━━━━━━━━━━━━━━  5/17 [nvidia-nccl-cu12]
#       Successfully uninstalled nvidia-curand-cu12-10.3.5.147━━  5/17 [nvidia-nccl-cu12]
#   Attempting uninstall: nvidia-cuda-runtime-cu12━━━━━━━━━━━━━━━━━━  6/17 [nvidia-curand-cu12]
#     Found existing installation: nvidia-cuda-runtime-cu12 12.4.127  6/17 [nvidia-curand-cu12]
#     Uninstalling nvidia-cuda-runtime-cu12-12.4.127:━━━━━━━━━━━  6/17 [nvidia-curand-cu12]
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.4.1270m  6/17 [nvidia-curand-cu12]
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12━━━━━━━━━━━━━━━━  6/17 [nvidia-curand-cu12]
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.4.1270m  6/17 [nvidia-curand-cu12]
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.4.127:━━━━━━━━━━━━━  6/17 [nvidia-curand-cu12]
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.4.127  6/17 [nvidia-curand-cu12]
#   Attempting uninstall: nvidia-cuda-cupti-cu12━━━━━━━━━━━━━━━━━━━━  8/17 [nvidia-cuda-nvrtc-cu12]
#     Found existing installation: nvidia-cuda-cupti-cu12 12.4.1270m  8/17 [nvidia-cuda-nvrtc-cu12]
#     Uninstalling nvidia-cuda-cupti-cu12-12.4.127:━━━━━━━━━━━━━  8/17 [nvidia-cuda-nvrtc-cu12]
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.4.127  8/17 [nvidia-cuda-nvrtc-cu12]
#   Attempting uninstall: nvidia-cublas-cu12m━━━━━━━━━━━━━━━━━━  9/17 [nvidia-cuda-cupti-cu12]
#     Found existing installation: nvidia-cublas-cu12 12.4.5.8━━  9/17 [nvidia-cuda-cupti-cu12]
#     Uninstalling nvidia-cublas-cu12-12.4.5.8:━━━━━━━━━━━━━━━━━  9/17 [nvidia-cuda-cupti-cu12]
#       Successfully uninstalled nvidia-cublas-cu12-12.4.5.8━━━━  9/17 [nvidia-cuda-cupti-cu12]
#   Attempting uninstall: nvidia-cusparse-cu12m━━━━━━━━━━━━━━━━ 10/17 [nvidia-cublas-cu12]
#     Found existing installation: nvidia-cusparse-cu12 12.3.1.1700m 10/17 [nvidia-cublas-cu12]
#     Uninstalling nvidia-cusparse-cu12-12.3.1.170:━━━━━━━━━━━━━ 10/17 [nvidia-cublas-cu12]
#       Successfully uninstalled nvidia-cusparse-cu12-12.3.1.170 10/17 [nvidia-cublas-cu12]
#   Attempting uninstall: nvidia-cufft-cu12m╸━━━━━━━━━━━━━━ 11/17 [nvidia-cusparse-cu12]
#     Found existing installation: nvidia-cufft-cu12 11.2.1.3━━━ 11/17 [nvidia-cusparse-cu12]
#     Uninstalling nvidia-cufft-cu12-11.2.1.3:━━━━━━━━━━━━━━ 11/17 [nvidia-cusparse-cu12]
#       Successfully uninstalled nvidia-cufft-cu12-11.2.1.3━━━━━ 11/17 [nvidia-cusparse-cu12]
#   Attempting uninstall: nvidia-cudnn-cu12╺━━━━━━━━━━━ 12/17 [nvidia-cufft-cu12]
#     Found existing installation: nvidia-cudnn-cu12 9.1.0.70━━━ 12/17 [nvidia-cufft-cu12]
#     Uninstalling nvidia-cudnn-cu12-9.1.0.70:0m━━━━━━━━━━━ 12/17 [nvidia-cufft-cu12]
#       Successfully uninstalled nvidia-cudnn-cu12-9.1.0.70━━━━━ 12/17 [nvidia-cufft-cu12]
#   Attempting uninstall: nvidia-cusolver-cu1291m╸━━━━━━━━━ 13/17 [nvidia-cudnn-cu12]
#     Found existing installation: nvidia-cusolver-cu12 11.6.1.9 13/17 [nvidia-cudnn-cu12]
#     Uninstalling nvidia-cusolver-cu12-11.6.1.9:m━━━━━━━━━ 13/17 [nvidia-cudnn-cu12]
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.1.9━━ 13/17 [nvidia-cudnn-cu12]
#   Attempting uninstall: torch━━━━━━━━━━━╸━━━━━━━ 14/17 [nvidia-cusolver-cu12]
#     Found existing installation: torch 2.2.2+cpu0m━━━━━━━ 14/17 [nvidia-cusolver-cu12]
#     Uninstalling torch-2.2.2+cpu:━━━━━━━━━━╺━━━━ 15/17 [torch]olver-cu12]
#       Successfully uninstalled torch-2.2.2+cpu0m╺━━━━ 15/17 [torch]
#   Attempting uninstall: torchaudio━━━━━━━━━╺━━━━ 15/17 [torch]
#     Found existing installation: torchaudio 2.6.0━━━━ 15/17 [torch]
#     Uninstalling torchaudio-2.6.0:━━━━━╺━━━━ 15/17 [torch]
#       Successfully uninstalled torchaudio-2.6.0m╺━━━━ 15/17 [torch]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17/17 [torchaudio]7 [torchaudio]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autogluon-multimodal 1.3.0 requires omegaconf<2.4.0,>=2.1.1, which is not installed.
# autogluon-multimodal 1.3.0 requires torch<2.7,>=2.2, but you have torch 2.7.0 which is incompatible.
# autogluon-multimodal 1.3.0 requires transformers[sentencepiece]<4.50,>=4.38.0, but you have transformers 4.52.3 which is incompatible.
# autogluon-timeseries 1.3.0 requires torch<2.7,>=2.2, but you have torch 2.7.0 which is incompatible.
# autogluon-timeseries 1.3.0 requires transformers[sentencepiece]<4.50,>=4.38.0, but you have transformers 4.52.3 which is incompatible.
# fastai 2.8.1 requires torch<2.7,>=1.10, but you have torch 2.7.0 which is incompatible.
# lightning 2.5.1.post0 requires packaging<25.0,>=20.0, but you have packaging 25.0 which is incompatible.
# torchvision 0.21.0 requires torch==2.6.0, but you have torch 2.7.0 which is incompatible.
# unsloth 2025.5.7 requires protobuf<4.0.0, but you have protobuf 4.25.7 which is incompatible.
# unsloth 2025.5.7 requires transformers!=4.47.0,==4.51.3, but you have transformers 4.52.3 which is incompatible.
# unsloth-zoo 2025.5.8 requires protobuf<4.0.0, but you have protobuf 4.25.7 which is incompatible.
# unsloth-zoo 2025.5.8 requires transformers!=4.47.0,==4.51.3, but you have transformers 4.52.3 which is incompatible.
# vllm 0.8.5.post1 requires torch==2.6.0, but you have torch 2.7.0 which is incompatible.
# vllm 0.8.5.post1 requires torchaudio==2.6.0, but you have torchaudio 2.7.0 which is incompatible.
# xformers 0.0.29.post2 requires torch==2.6.0, but you have torch 2.7.0 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 sympy-1.14.0 torch-2.7.0 torchaudio-2.7.0 triton-3.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, multilabel_confusion_matrix

mcm = multilabel_confusion_matrix(y_true, y_pred)
for i, label_mcm in enumerate(mcm):
    print(f"Label {i+1}:")
    print(label_mcm)

references = predict_df['Gemini_Transcript ไว้แก้'].to_list()
hypothesis = predict_df['denoised_text'].to_list()
error_metrics = jiwer.compute_measures(references, hypothesis)
error_metrics['wer']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, multilabel_confusion_matrix
# ----> 3 mcm = multilabel_confusion_matrix(y_true, y_pred)
#       4 for i, label_mcm in enumerate(mcm):
#       5     print(f"Label {i+1}:")
#
# NameError: name 'y_true' is not defined

# %%
import os
import evaluate
import pandas as pd
import torch
import torchaudio
from torch.utils.data import Dataset
from datasets import load_dataset, Audio
from transformers import (
    WhisperFeatureExtractor,
    WhisperTokenizer,
    WhisperProcessor,
    WhisperForConditionalGeneration,
    Seq2SeqTrainingArguments,
    Seq2SeqTrainer,
    pipeline
)
from tqdm.notebook import tqdm
from pythainlp.tokenize import word_tokenize
from huggingface_hub import login
from dataclasses import dataclass
import string
from torch.utils.data import DataLoader
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 import os
# ----> 2 import evaluate
#       3 import pandas as pd
#       4 import torch
#
# File ~/.local/lib/python3.10/site-packages/evaluate/__init__.py:29
#      25 SCRIPTS_VERSION = "main" if version.parse(__version__).is_devrelease else __version__
#      27 del version
# ---> 29 from .evaluation_suite import EvaluationSuite
#      30 from .evaluator import (
#      31     AudioClassificationEvaluator,
#      32     AutomaticSpeechRecognitionEvaluator,
#    (...)
#      42     evaluator,
#      43 )
#      44 from .hub import push_to_hub
#
# File ~/.local/lib/python3.10/site-packages/evaluate/evaluation_suite/__init__.py:10
#       7 from datasets import Dataset, DownloadConfig, DownloadMode, load_dataset
#       8 from datasets.utils.version import Version
# ---> 10 from ..evaluator import evaluator
#      11 from ..loading import evaluation_module_factory
#      12 from ..utils.logging import get_logger
#
# File ~/.local/lib/python3.10/site-packages/evaluate/evaluator/__init__.py:17
#       1 # Copyright 2022 The HuggingFace Datasets Authors and the TensorFlow Datasets Authors.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      16 try:
# ---> 17     from transformers.pipelines import SUPPORTED_TASKS as SUPPORTED_PIPELINE_TASKS
#      18     from transformers.pipelines import TASK_ALIASES
#      19     from transformers.pipelines import check_task as check_pipeline_task
#
# File /data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/pipelines/__init__.py:26
#      24 from ..dynamic_module_utils import get_class_from_dynamic_module
#      25 from ..feature_extraction_utils import PreTrainedFeatureExtractor
# ---> 26 from ..image_processing_utils import BaseImageProcessor
#      27 from ..models.auto.configuration_auto import AutoConfig
#      28 from ..models.auto.feature_extraction_auto import FEATURE_EXTRACTOR_MAPPING, AutoFeatureExtractor
#
# File /data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/image_processing_utils.py:22
#      19 import numpy as np
#      21 from .image_processing_base import BatchFeature, ImageProcessingMixin
# ---> 22 from .image_transforms import center_crop, normalize, rescale
#      23 from .image_utils import ChannelDimension, get_image_size
#      24 from .utils import logging
#
# File /data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/image_transforms.py:21
#      17 from typing import Optional, Union
#      19 import numpy as np
# ---> 21 from .image_utils import (
#      22     ChannelDimension,
#      23     ImageInput,
#      24     get_channel_dimension_axis,
#      25     get_image_size,
#      26     infer_channel_dimension_format,
#      27 )
#      28 from .utils import ExplicitEnum, TensorType, is_jax_tensor, is_tf_tensor, is_torch_tensor
#      29 from .utils.import_utils import (
#      30     is_flax_available,
#      31     is_tf_available,
#    (...)
#      34     requires_backends,
#      35 )
#
# File /data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/image_utils.py:59
#      56     PILImageResampling = PIL.Image
#      58 if is_torchvision_available():
# ---> 59     from torchvision.transforms import InterpolationMode
#      61     pil_torch_interpolation_mapping = {
#      62         PILImageResampling.NEAREST: InterpolationMode.NEAREST_EXACT,
#      63         PILImageResampling.BOX: InterpolationMode.BOX,
#    (...)
#      67         PILImageResampling.LANCZOS: InterpolationMode.LANCZOS,
#      68     }
#      69 else:
#
# File /data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/torchvision/__init__.py:10
#       7 # Don't re-order these, we need to load the _C extension (done when importing
#       8 # .extensions) before entering _meta_registrations.
#       9 from .extension import _HAS_OPS  # usort:skip
# ---> 10 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#      12 try:
#      13     from .version import __version__  # noqa: F401
#
# File /data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/torchvision/_meta_registrations.py:26
#      20         return fn
#      22     return wrapper
#      25 @register_meta("roi_align")
# ---> 26 def meta_roi_align(input, rois, spatial_scale, pooled_height, pooled_width, sampling_ratio, aligned):
#      27     torch._check(rois.size(1) == 5, lambda: "rois must have shape as Tensor[K, 5]")
#      28     torch._check(
#      29         input.dtype == rois.dtype,
#      30         lambda: (
#    (...)
#      33         ),
#      34     )
#
# File /data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/torchvision/_meta_registrations.py:18, in register_meta.<locals>.wrapper(fn)
#      17 def wrapper(fn):
# ---> 18     if torchvision.extension._has_ops():
#      19         get_meta_lib().impl(getattr(getattr(torch.ops.torchvision, op_name), overload_name), fn)
#      20     return fn
#
# AttributeError: partially initialized module 'torchvision' has no attribute 'extension' (most likely due to a circular import)

# %%
os.environ["WANDB_MODE"] = "offline"

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
lang = "th"
task = "transcribe"
model_name = "biodatlab/whisper-th-medium-combined"

# %% [markdown]
# ## Load Model

# %%
model = WhisperForConditionalGeneration.from_pretrained(model_name)
model.generation_config.language = lang
model.generation_config.task = task
model.generation_config.forced_decoder_ids = None
model = model.to(device)

# %%
class CustomDataset(Dataset):
    def __init__(self, 
        csv_file: str, 
        audio_folder: str, 
        target_sr: int = 16000,
        feature_extractor: WhisperFeatureExtractor = None,
        tokenizer: WhisperTokenizer = None
    ):
        super(CustomDataset, self).__init__()
        self.audio_folder = audio_folder
        self.target_sr = target_sr
        self.csv_file = pd.read_csv(csv_file)
        self.csv_file['audio'] = self.csv_file['audio'].apply(
            lambda x: os.path.join(audio_folder, x)
        )
        self.csv_file['sentence'] = self.csv_file['sentence'].apply(
            lambda txt: txt.translate(str.maketrans('', '', string.punctuation))
        )
        
        self.tokenizer = tokenizer
        self.feature_extractor = feature_extractor

    def __len__(self):
        return self.csv_file.shape[0]
    
    def __getitem__(self, idx):
        try:
            audio_path, sentence = self.csv_file.iloc[idx]
            
            # Try loading with torchaudio
            try:
                waveform, sampling_rate = torchaudio.load(audio_path)
            except:
                # If torchaudio fails, try using soundfile
                import soundfile as sf
                waveform, sampling_rate = sf.read(audio_path)
                waveform = torch.from_numpy(waveform).T
                if len(waveform.shape) == 1:
                    waveform = waveform.unsqueeze(0)
            
            if sampling_rate != self.target_sr:
                resampler = torchaudio.transforms.Resample(sampling_rate, self.target_sr)
                waveform = resampler(waveform)
                sampling_rate = self.target_sr
            
            array = waveform.detach().numpy().flatten()    

            input_features = self.feature_extractor(array, sampling_rate=sampling_rate).input_features[0]
            labels = self.tokenizer(sentence).input_ids

            return dict(
                input_features=input_features,
                labels=labels
            )
        except Exception as e:
            print(f"Error loading {audio_path}: {str(e)}")
            # Return a default/empty sample
            return dict(
                input_features=torch.zeros((80, 3000)),
                labels=self.tokenizer("").input_ids
            )

# %%
feature_extractor = WhisperFeatureExtractor.from_pretrained(model_name)
tokenizer = WhisperTokenizer.from_pretrained(model_name, language=lang, task=task)

# %%
processor = WhisperProcessor.from_pretrained(model_name, language=lang, task=task)

# %% [markdown]
# ## PATH DATA FILE CSV+AUDIO_FOLDER

# %%
datasets = {
    "train": CustomDataset(
        csv_file="/data/502507_pre/502507_pre/hcu-speech-recognition-challenge-2025/train.csv",
        audio_folder="/data/502507_pre/502507_pre/hcu-speech-recognition-challenge-2025/train",
        feature_extractor=feature_extractor,
        tokenizer=tokenizer,
    ),  
    "dev": CustomDataset(
        csv_file="/data/502507_pre/502507_pre/hcu-speech-recognition-challenge-2025/dev.csv",
        audio_folder="/data/502507_pre/502507_pre/hcu-speech-recognition-challenge-2025/dev",
        feature_extractor=feature_extractor,
        tokenizer=tokenizer,
    )
}

# %% [markdown]
# ## Data Collator

# %%
@dataclass
class DataCollatorSpeechSeq2SeqWithPadding:

    def __init__(self, processor, decoder_start_token_id):
        self.processor = processor
        self.decoder_start_token_id = decoder_start_token_id

    def __call__(self, features):

        # Prepare input features by padding and converting to tensor
        input_features = [{"input_features": feature["input_features"]} for feature in features]
        batch = self.processor.feature_extractor.pad(input_features, return_tensors="pt")

        # Prepare labels by padding and converting to tensor
        label_features = [{"input_ids": feature["labels"]} for feature in features]
        labels_batch = self.processor.tokenizer.pad(label_features, return_tensors="pt")

        # Mask padding tokens in labels
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        # Remove the decoder start token
        if (labels[:, 0] == self.decoder_start_token_id).all().cpu().item():
            labels = labels[:, 1:]

        batch["labels"] = labels
        return batch

# %%
data_collator = DataCollatorSpeechSeq2SeqWithPadding(
    processor=processor,
    decoder_start_token_id=model.config.decoder_start_token_id,
)

# %% [markdown]
# ## Eval Metrics CER

# %%
metric = evaluate.load("cer")

def compute_metrics(pred):
    pred_ids = pred.predictions
    label_ids = pred.label_ids

    label_ids[label_ids == -100] = tokenizer.pad_token_id

    pred_str = tokenizer.batch_decode(pred_ids, skip_special_tokens=True)
    label_str = tokenizer.batch_decode(label_ids, skip_special_tokens=True)

    cer = 100 * metric.compute(predictions=pred_str, references=label_str)

    return {"cer": cer}

# %% [markdown]
# ## Fine-tuning

# %%
from accelerate import Accelerator

# %%
# Add before trainer initialization
accelerator = Accelerator()
model = accelerator.prepare(model)

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir="/data/Chuniji/texttospeech/outss2",
    per_device_train_batch_size=8,
    gradient_accumulation_steps=4,
    num_train_epochs=1.0,
    learning_rate=9e-6,
    gradient_checkpointing=True,
    fp16=True,
    bf16=False,
    optim="adamw_torch_fused",
    eval_strategy="epoch",
    per_device_eval_batch_size=1,
    predict_with_generate=True,
    generation_max_length=64,
    save_strategy="epoch",
    save_total_limit=5,
    logging_steps=100,
    report_to=None,
    push_to_hub=False,
    # Add these lines:
    no_cuda=False if torch.cuda.is_available() else True,
    ddp_find_unused_parameters=False,
    local_rank=-1
)

# %%
trainer = Seq2SeqTrainer(
    args=training_args,
    model=model,
    train_dataset=datasets['train'],
    eval_dataset=datasets['dev'],
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    tokenizer=processor.feature_extractor
)
trainer = accelerator.prepare(trainer)
# Out:
# /tmp/ipykernel_70818/2347717825.py:10: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(

# %%
processor.save_pretrained(training_args.output_dir)
# Out:
# []

# %%
trainer.train()
# Out:
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.43.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
#     <div>
#
#       <progress value='50' max='50' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [50/50 07:27, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Cer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.084174</td>
#       <td>22.163196</td>
#     </tr>
#   </tbody>
# </table><p>
# Error loading /data/502507_pre/502507_pre/hcu-speech-recognition-challenge-2025/train/650020_AUG_1088.mp3: Error opening '/data/502507_pre/502507_pre/hcu-speech-recognition-challenge-2025/train/650020_AUG_1088.mp3': System error.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# /data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/modeling_utils.py:3464: UserWarning: Moving the following attributes in the config to the generation config: {'max_length': 448, 'begin_suppress_tokens': [220, 50257]}. You are seeing this warning because you've set generation parameters in the model config, as opposed to in the generation config.
#   warnings.warn(
# TrainOutput(global_step=50, training_loss=0.3283563232421875, metrics={'train_runtime': 453.7785, 'train_samples_per_second': 3.524, 'train_steps_per_second': 0.11, 'total_flos': 1.63194724712448e+18, 'train_loss': 0.3283563232421875, 'epoch': 1.0})

# %%
# !apt-get install -y libsndfile1
# %pip install soundfile

# %% [markdown]
# ## Inference

# %%
checkpoints = []
for root, dirs, files in os.walk("/data/Chuniji/texttospeech/outss2"):
    for d in sorted(dirs):
        if 'checkpoint' in d:
            checkpoints.append(d)
            print(d)
print(checkpoints)
# Out:
# checkpoint-50
# checkpoint-525
# checkpoint-850
# ['checkpoint-50', 'checkpoint-525', 'checkpoint-850']

# %%
dataset_folder_path="/data/week4data/cleaned_test"
# sub_df=pd.read_csv("/kaggle/input/dsi-443-tu-speech-recognition-challenge/datasets/sample_submission.csv")
test_df=pd.read_csv("/data/502507_pre/502507_pre/week4/test_id.csv")

# %%
def cut_word(txt):
    txt.replace(" ", "")
    txt = txt.strip()
    txt = " ".join(word_tokenize(text=txt, engine="newmm"))
    return txt

# %%
# %pip install --upgrade transformers

# %%
# %pip install --upgrade transformers torch torchaudio
# %pip install -U accelerate
# %pip install --force-reinstall transformers

# %%
# Get the last checkpoint path
last_checkpoint_path = os.path.join(training_args.output_dir, checkpoints[-1]) if checkpoints else model_name

# Load model and tokenizer directly
model = WhisperForConditionalGeneration.from_pretrained(last_checkpoint_path)

# %% [markdown]
# ## TEST CHUNK

# %%
from transformers import WhisperTokenizer, pipeline, WhisperForConditionalGeneration
import torch
import os

# Setup device
device = "cuda" if torch.cuda.is_available() else "cpu"

# Set your local model directory
base_model_path = "/data/Chuniji/model"

# Load model and tokenizer directly
model = WhisperForConditionalGeneration.from_pretrained(last_checkpoint_path)
tokenizer = WhisperTokenizer.from_pretrained(model_name, language=lang, task=task)

# Move model to device
model = model.to(device)

# Create pipeline
pipe = pipeline(
    task="automatic-speech-recognition",
    model=model,
    tokenizer=tokenizer,
    feature_extractor=processor.feature_extractor,
    chunk_length_s=15,
    device=0 if device == "cuda" else -1
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 12
#       9 base_model_path = "/data/Chuniji/model"
#      11 # Load model and tokenizer directly
# ---> 12 model = WhisperForConditionalGeneration.from_pretrained(last_checkpoint_path)
#      13 tokenizer = WhisperTokenizer.from_pretrained(model_name, language=lang, task=task)
#      15 # Move model to device
#
# NameError: name 'last_checkpoint_path' is not defined

# %%
pipe.model.eval()
# Out:
# WhisperForConditionalGeneration(
#   (model): WhisperModel(
#     (encoder): WhisperEncoder(
#       (conv1): Conv1d(80, 1024, kernel_size=(3,), stride=(1,), padding=(1,))
#       (conv2): Conv1d(1024, 1024, kernel_size=(3,), stride=(2,), padding=(1,))
#       (embed_positions): Embedding(1500, 1024)
#       (layers): ModuleList(
#         (0-23): 24 x WhisperEncoderLayer(
#           (self_attn): WhisperSdpaAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=False)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#     (decoder): WhisperDecoder(
#       (embed_tokens): Embedding(51865, 1024, padding_idx=50257)
#       (embed_positions): WhisperPositionalEmbedding(448, 1024)
#       (layers): ModuleList(
#         (0-23): 24 x WhisperDecoderLayer(
#           (self_attn): WhisperSdpaAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=False)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): WhisperSdpaAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=False)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (proj_out): Linear(in_features=1024, out_features=51865, bias=False)
# )

# %% [markdown]
# ## TEST CHUNK

# %%
text = pipe('/data/week4data/audio-understanding/speechs/speechs/train/d76f8990-f74f-4f11-8bc1-ada4928725ad.wav')["text"]
text
# Out:
# /data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# 'ดิฉันชื่อวิภดา หรือเรียกว่าวิวก็ได้ค่ะ เป็นที่ปรึกษาจากธนาคารไทยพาณิชย์ วันนี้ได้รับมอบหมายให้เข้ามาพูดคุยกับคุณผชน เกี่ยวกับการปรับเปลี่ยนแผนการเงินบางส่วน เพื่อให้การบริหารพอร์ตของคุณาชนเหมาะสมกับเป้าหมายในระยะยาวมากขึ้น ค่ะ ในการพูดคุยครั้งนี้ ดิฉันจะช่วยชี้แนะแนวทางในการลดความเสี่ยง รวมถึงเพิ่มโอกาสในการสร้างผลตอบแทนที่ดียิ่งขึ้น ซึ่งทั้งหมดนี้จะอิงกับข้อมูลการลงทุนของคุณพชรพลครับ นอกจากนี้ยังมีข้อมูลอัปเดตที่สำคัญจากสถานการณ์ตลาดที่ดิฉันเตรียมมา เพื่อช่วยให้การตัดสินใจของคุณแม่นยำยิ่งขึ้นค่ะ ดิฉันขอเวลา 20 นาทีสำหรับการพูดคุยครั้งนี้ แต่พยายามไม่ใช้เวลานานจนเกินไป หมายทราบว่าคุณเภชรพลสะดวกที่จะพูดคุยในช่วงนี้หรือยังคะ'

# %%
# %pip install -U ipywidgets

# %%
# %pip install -U ipywidgets jupyter
# !jupyter nbextension enable --py widgetsnbextension

# %% [markdown]
# ## TRANSCIRP PART

# %%
from tqdm import tqdm  # Change this import

pipe.model.eval()
for i in tqdm(range(len(test_df)), desc="Processing audio files"):
    audio_path = os.path.join(dataset_folder_path, test_df.iloc[i]['audio'])
    with torch.no_grad():  
        text = pipe(audio_path)["text"]
        # text = cut_word(text)
    test_df.at[i, "sentence"] = text
# Out:
# Processing audio files:   0%|          | 0/300 [00:00<?, ?it/s]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:   0%|          | 1/300 [00:03<17:58,  3.61s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:   1%|          | 2/300 [00:05<14:19,  2.88s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:   1%|          | 3/300 [00:09<14:52,  3.00s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:   1%|▏         | 4/300 [00:17<26:12,  5.31s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:   2%|▏         | 5/300 [00:23<26:27,  5.38s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:   2%|▏         | 6/300 [00:30<28:38,  5.85s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:   2%|▏         | 7/300 [00:38<33:02,  6.77s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:   3%|▎         | 8/300 [00:41<27:00,  5.55s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:   3%|▎         | 9/300 [00:54<36:56,  7.62s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:   3%|▎         | 10/300 [01:00<35:47,  7.41s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:   4%|▎         | 11/300 [01:06<33:36,  6.98s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:   4%|▍         | 12/300 [01:12<31:11,  6.50s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:   4%|▍         | 13/300 [01:31<50:07, 10.48s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:   5%|▍         | 14/300 [01:42<50:26, 10.58s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:   5%|▌         | 15/300 [01:49<44:11,  9.30s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:   5%|▌         | 16/300 [01:55<40:07,  8.48s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:   6%|▌         | 17/300 [02:03<39:03,  8.28s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:   6%|▌         | 18/300 [02:11<38:31,  8.20s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:   6%|▋         | 19/300 [02:12<28:33,  6.10s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:   7%|▋         | 20/300 [02:19<28:41,  6.15s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:   7%|▋         | 21/300 [02:25<29:22,  6.32s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:   7%|▋         | 22/300 [02:33<31:21,  6.77s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:   8%|▊         | 23/300 [02:42<34:54,  7.56s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:   8%|▊         | 24/300 [02:48<32:30,  7.07s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:   8%|▊         | 25/300 [02:50<25:17,  5.52s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:   9%|▊         | 26/300 [02:57<26:45,  5.86s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:   9%|▉         | 27/300 [03:05<29:25,  6.47s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:   9%|▉         | 28/300 [03:10<28:08,  6.21s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:  10%|▉         | 29/300 [03:25<38:55,  8.62s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:  10%|█         | 30/300 [03:31<35:46,  7.95s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:  10%|█         | 31/300 [03:33<27:24,  6.11s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:
/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:  95%|█████████▌| 286/300 [31:57<01:43,  7.41s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:  96%|█████████▌| 287/300 [32:05<01:39,  7.64s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:  96%|█████████▌| 288/300 [32:15<01:39,  8.32s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:  96%|█████████▋| 289/300 [32:22<01:28,  8.05s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:  97%|█████████▋| 290/300 [32:29<01:17,  7.75s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:  97%|█████████▋| 291/300 [32:37<01:08,  7.56s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:  97%|█████████▋| 292/300 [32:47<01:06,  8.32s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:  98%|█████████▊| 293/300 [32:54<00:55,  7.88s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:  98%|█████████▊| 294/300 [33:02<00:48,  8.03s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:  98%|█████████▊| 295/300 [33:08<00:36,  7.39s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:  99%|█████████▊| 296/300 [33:13<00:27,  6.82s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:  99%|█████████▉| 297/300 [33:24<00:23,  7.90s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files:  99%|█████████▉| 298/300 [33:38<00:19,  9.69s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files: 100%|█████████▉| 299/300 [33:43<00:08,  8.54s/it]/data/Chuniji/chunenvi/ttotchuniji/lib/python3.10/site-packages/transformers/models/whisper/generation_whisper.py:573: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Processing audio files: 100%|██████████| 300/300 [33:58<00:00,  6.80s/it]

# %%
test_df
# Out:
#                                         audio  \
# 0    2e378ce7-b5f5-49b7-a337-0bc64b1115cd.wav
# 1    70e43e4b-42f2-40f8-9822-2ec5ee0c94d4.wav
# 2    b1b69e87-0a65-4aac-9eeb-910328f8bb1f.wav
# 3    292e0419-aed1-43d0-aa60-9635dc80574b.wav
# 4    51f656f7-7558-4e4b-ab0a-fa91a772d196.wav
# ..                                        ...
# 295  dd74a676-a365-42ee-8793-89dc1b732596.wav
# 296  4ee7be59-b578-48a1-9b2d-74e5e18d845d.wav
# 297  e7089064-4bfa-42d6-8f53-abfded8653b8.wav
# 298  a43136f2-aed3-41d3-9921-9abbdd5c6f8e.wav
# 299  5623f1f5-c02e-4db9-9a41-2352917f3005.wav
#
#                                               sentence
# 0    เม้นท์มาคุยกับคุณวัณนิดาในวันนี้เพื่ออยากจะแนะ...
# 1    ดิฉันชื่อจิตาเป็นที่ปรึกษาทางการเงินค่ะก่อนเริ...
# 2    ผมปั๊บครับ เป็นที่ปรึกษาทางการเงินแก่ธนาคารไทย...
# 3    สวัสดีค่ะ คุณบุญธิชา ดิฉันชื่อบุนดา หรือเรียกว...
# 4    บุหรี่ชั้นชื่อพัทธ์ ตรา อิน ท ว ท น เป็นที่ปรึ...
# ..                                                 ...
# 295  ชื่อ นายสมบัติ บุญการจน หรือเรียกสั้นๆว่า บัฏ ...
# 296  สวัสดีค่ะ คุณวิชากร ดิชั้นชื่อ นางสาวรวีวัณย์ ...
# 297  สวัสดีครับ สวัสดีครับ สวัสดีครับ สวัสดีครับ สว...
# 298  ชื่อ นายอิทธิมล สวัสดิคุณ หรือเรียกผมว่า มิ้น ...
# 299  ดิฉันชื่อญาณาศิริ นักศึกษานาอุดมภูมิ หรือเรียก...
#
# [300 rows x 2 columns]

# %%
test_df.to_csv("test_text.csv", index=False)

# %%
trainer.save_model("/data/Chuniji/texttospeech/final_model")
