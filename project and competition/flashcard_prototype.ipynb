# %%
# !git clone https://github.com/suwapatsuw3/flashcard-initial
# Out:
# Cloning into 'flashcard-initial'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), 78.37 KiB | 3.41 MiB/s, done.

# %%
import gspread
import pandas as pd
from google.auth import default
from google.colab import auth
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# %%
spreadsheet = gc.open_by_key('1XtGCUEIC6qjfdOMAXT7RSvvD0hh1VY_tJBkk_uzkoiU')
worksheet = spreadsheet.get_worksheet(0)
df = pd.DataFrame(worksheet.get())
df.columns = df.iloc[0]
df = df.drop(0)
df.head()
# Out:
# 0        eng           tha
# 1   deprived       ขาดแคลน
# 2  viewpoint        มุมมอง
# 3      lapse   ความล้มเหลว
# 4     impair  ทำให้เสียหาย
# 5   profound   significant

# %%
len(df['eng'])
# Out:
# 1105

# %%
import random
import time

# %%
each = 300
start = 3
if (start+1)*each > len(df['eng']):
  w = df[start*each:]
else:
  w = df[start*each:(start+1)*each]

# %%
while len(w['eng'])!=0:
  #break
  w = w.reset_index(drop=True)
  b = list(range(len(w['eng'])))
  random.shuffle(b)
  r=[]
  for i in b:
    print(w['eng'][i])
    time.sleep(1)
    c = input(f"{w['tha'][i]} : ")
    if c == ';':
      r.append(i)
    if c == 'pause':
      break
  w = w.drop(index=r)
  print('-'*10)
  if c == 'pause':
    break
print('done')
# Out:
# foraged
# หาอาหาร :
# pathentic
# น่าสงสาร, น่าสมเพช :
# sommelier
# ผู้เชี่ยวชาญด้านไวน์ :
# legacy
# มรดก : ;
# moderately
# อย่างพอประมาณ :
# suppress
# ปราบปราม : ;
# plaintiff
# โจทก์ :
# let something slip
# พูดหลุดออกมาโดยไม่ตั้งใจ : ;
# intellectual
# ทางปัญญา, ผู้มีสติปัญญา : ;
# expose
# เปิดเผย : ;
# floatation
# การลอยตัว :
# subsequently
# ต่อมา : ;
# overawed
# ตะลึง : ;
# abate
# บรรเทา : ;
# emdorse
# รับรอง, สนับสนุน : ;
# deem
# ถือว่า : ;
# vigilant
# ระมัดระวัง, เฝ้าระวัง :
# unity
# ความเป็นเอกภาพ : ;
# confide in
# ไว้วางใจ, เปิดใจกับ : ;
# blab
# พูดมากเกินไป :
# zero in
# มุ่งเป้า : ;
# vicinity
# บริเวณใกล้เคียง :
# robustly
# อย่างแข็งแกร่ง, อย่างหนักแน่น :
# disguise
# ปลอมตัว : ;
# encroach
# intrude = invade = บุกรุก : ;
# wind up
# จบลง, ลงเอย : ;
# owing
# ค้างชำระ : ;
# haul
# ลาก, ขนย้าย :
# fictitious
# แต่งขึ้น, ไม่จริง : ;
# affair
# เรื่องราว, ความสัมพันธ์เชิงชู้สาว (กิ๊ก) : ;
# compassionate
# มีความเห็นอกเห็นใจ : ;
# intoxicate
# ...
